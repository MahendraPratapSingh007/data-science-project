# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv('E:/Project/Python/Data files/heroes_information.csv')
marvel.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
marvel.shape
# Out:
# (734, 11)

# %%
marvel['Alignment'].value_counts()
# Out:
# good       496
# bad        207
# neutral     24
# -            7
# Name: Alignment, dtype: int64

# %%
marvel[marvel['Alignment']=='good']
# Out:
#      Unnamed: 0             name  Gender Eye color            Race  \
# 0             0           A-Bomb    Male    yellow           Human
# 1             1       Abe Sapien    Male      blue   Icthyo Sapien
# 2             2         Abin Sur    Male      blue         Ungaran
# 6             6      Adam Monroe    Male      blue               -
# 7             7     Adam Strange    Male      blue           Human
# ..          ...              ...     ...       ...             ...
# 728         728     Yellowjacket    Male      blue           Human
# 729         729  Yellowjacket II  Female      blue           Human
# 730         730             Ymir    Male     white     Frost Giant
# 731         731             Yoda    Male     brown  Yoda's species
# 732         732          Zatanna  Female      blue           Human
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# 0             No Hair   203.0      Marvel Comics          -      good   441.0
# ...

# %%
good=marvel[marvel['Alignment']=='good']

# %%
good.head()
# Out:
#    Unnamed: 0          name Gender Eye color           Race Hair color  \
# 0           0        A-Bomb   Male    yellow          Human    No Hair
# 1           1    Abe Sapien   Male      blue  Icthyo Sapien    No Hair
# 2           2      Abin Sur   Male      blue        Ungaran    No Hair
# 6           6   Adam Monroe   Male      blue              -      Blond
# 7           7  Adam Strange   Male      blue          Human      Blond
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 6   -99.0       NBC - Heroes          -      good   -99.0
# 7   185.0          DC Comics          -      good    88.0

# %%
good.sort_values(by=['Height'],ascending=False)
# Out:
#      Unnamed: 0             name  Gender Eye color             Race  \
# 255         255    Fin Fang Foom    Male       red  Kakarantharaian
# 302         302            Groot    Male    yellow   Flora Colossus
# 718         718        Wolfsbane  Female     green                -
# 575         575        Sasquatch    Male       red                -
# 730         730             Ymir    Male     white      Frost Giant
# ..          ...              ...     ...       ...              ...
# 242         242           Energy  Female         -                -
# 526         526        Power Man    Male         -           Mutant
# 232         232     Dr Manhattan    Male     white   Human / Cosmic
# 227         227        Donatello    Male     green           Mutant
# 356         356  Jean-Luc Picard    Male         -            Human
#
#     Hair color  Height       Publisher Skin color Alignment  Weight
# 255    No Hair   975.0   Marvel Comics      green      good    18.0
# ...
